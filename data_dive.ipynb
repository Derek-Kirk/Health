# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('early_wakeup_health_dataset.csv')
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#   person_id  age  gender  height_cm  weight_kg    bmi    country  \
# 0    P00001   76  Female      158.8       62.1  24.63      Italy
# 1    P00002   49  Female      160.9       68.5  26.45        USA
# 2    P00003   51  Female      151.9       54.8  23.77     Mexico
# 3    P00004   48    Male      167.6       81.3  28.93  Australia
# 4    P00005   68  Female      171.9       75.4  25.51        USA
#
#           occupation marital_status wake_up_time  ... obesity_risk  \
# 0       Entrepreneur        Widowed        08:59  ...          Low
# 1         Freelancer         Single        06:35  ...       Medium
# 2              Nurse         Single        07:31  ...          Low
# 3            Laborer         Single        08:36  ...       Medium
# 4  Software Engineer        Married        07:07  ...       Medium
#
#    hypertension_risk  diabetes_risk  cardiovascular_risk  sleep_disorder_risk  \
# 0               High         Medium               Medium                  Low
# ...

# %%
scores = data.columns[data.columns.str.contains('score')]
risks = data.columns[data.columns.str.contains('risk')]
features = data.columns[~data.columns.isin(scores) & ~data.columns.isin(risks)][1:]

# %%
features
# Out:
# Index(['age', 'gender', 'height_cm', 'weight_kg', 'bmi', 'country',
#        'occupation', 'marital_status', 'wake_up_time', 'sleep_time',
#        'sleep_duration_hours', 'number_of_night_awakenings',
#        'weekend_sleep_difference_hours', 'nap_frequency_per_week',
#        'screen_time_before_bed_hours', 'exercise_frequency_per_week',
#        'exercise_duration_minutes', 'exercise_type', 'daily_steps',
#        'morning_workout', 'workout_intensity', 'gym_member',
#        'daily_calorie_intake', 'water_intake_liters', 'fruit_intake_per_day',
#        'vegetable_intake_per_day', 'protein_intake_grams',
#        'sugary_drinks_per_week', 'fast_food_meals_per_week', 'smoking_status',
#        'alcohol_consumption', 'stress_level', 'working_hours_per_day',
#        'sitting_hours_per_day', 'outdoor_time_hours', 'meditation_practice',
#        'resting_heart_rate', 'systolic_bp', 'diastolic_bp',
#        'cholesterol_level', 'blood_sugar_level', 'fitness_level',
# ...
